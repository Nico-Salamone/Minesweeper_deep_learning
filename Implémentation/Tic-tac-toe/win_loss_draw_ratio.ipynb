# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
import random
import numpy as np

import tic_tac_toe as ttt
import data_set as ds
import neural_network as nn

seed = 867342
data_set_file_name = "data_set.csv"
model_file_name = "model.h5"

random.seed(seed)
np.random.seed(seed)

data_set = ds.read_data_set(data_set_file_name)
data_set = nn.format_data_for_neural_network(data_set, nn.get_win_loss_draw_ratio)
#training_set = data_set
training_set = random.sample(data_set, int(len(data_set) / 2))

model = nn.create_fit_model(training_set, model_file_name = model_file_name)

#test_set = data_set
test_set = list(set(data_set) - set(training_set))
x, y_true = nn.split_data_set_in_x_y_true(test_set)
y_pred = model.predict([nn.convert_grid_for_neural_network(grid) for grid in x])
# Out:
# Using TensorFlow backend.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Epoch 1/100
# 2739/2739 [==============================] - 1s 183us/step - loss: 0.0647 - mean_squared_error: 0.0647 - mean_absolute_error: 0.1732
# Epoch 2/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0399 - mean_squared_error: 0.0399 - mean_absolute_error: 0.1330
# Epoch 3/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0188 - mean_squared_error: 0.0188 - mean_absolute_error: 0.0963
# Epoch 4/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0146 - mean_squared_error: 0.0146 - mean_absolute_error: 0.0834
# Epoch 5/100
# 2739/2739 [==============================] - 0s 104us/step - loss: 0.0127 - mean_squared_error: 0.0127 - mean_absolute_error: 0.0782
# Epoch 6/100
# 2739/2739 [==============================] - 0s 88us/step - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0710
# Epoch 7/100
# 2739/2739 [==============================] - 0s 85us/step - loss: 0.0097 - mean_squared_error: 0.0097 - mean_absolute_error: 0.0670
# Epoch 8/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0087 - mean_squared_error: 0.0087 - mean_absolute_error: 0.0636
# Epoch 9/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0080 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0611
# Epoch 10/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0590
# Epoch 11/100
# 2739/2739 [==============================] - 0s 86us/step - loss: 0.0069 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0561
# Epoch 12/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0064 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0538
# Epoch 13/100
# 2739/2739 [==============================] - 0s 85us/step - loss: 0.0059 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0520
# Epoch 14/100
# 2739/2739 [==============================] - 0s 91us/step - loss: 0.0055 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0493
# Epoch 15/100
# 2739/2739 [==============================] - 0s 89us/step - loss: 0.0052 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0477 0s - loss: 0.0043 - mean_squared_error: 0.0043 - mean_absolute_error
# Epoch 16/100
# 2739/2739 [==============================] - 0s 88us/step - loss: 0.0051 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0479
# Epoch 17/100
# 2739/2739 [==============================] - 0s 89us/step - loss: 0.0047 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0455
# Epoch 18/100
# 2739/2739 [==============================] - 0s 88us/step - loss: 0.0045 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0445
# Epoch 19/100
# 2739/2739 [==============================] - 0s 87us/step - loss: 0.0042 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0429
# Epoch 20/100
# 2739/2739 [==============================] - 0s 88us/step - loss: 0.0039 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0415
# Epoch 21/100
# 2739/2739 [==============================] - 0s 89us/step - loss: 0.0038 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0408
# Epoch 22/100
# 2739/2739 [==============================] - 0s 89us/step - loss: 0.0036 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0398
# Epoch 23/100
# 2739/2739 [==============================] - 0s 91us/step - loss: 0.0035 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0390
# Epoch 24/100
# 2739/2739 [==============================] - 0s 91us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0380
# Epoch 25/100
# 2739/2739 [==============================] - 0s 89us/step - loss: 0.0032 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0373
# Epoch 26/100
# 2739/2739 [==============================] - 0s 89us/step - loss: 0.0031 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0366
# Epoch 27/100
# 2739/2739 [==============================] - 0s 91us/step - loss: 0.0030 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0360
# Epoch 28/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0029 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0350
# Epoch 29/100
# 2739/2739 [==============================] - 0s 88us/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0346
# Epoch 30/100
# 2739/2739 [==============================] - 0s 87us/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0347
# Epoch 31/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0336
# Epoch 32/100
# 2739/2739 [==============================] - 0s 98us/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0329
# Epoch 33/100
# 2739/2739 [==============================] - 0s 99us/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0325
# Epoch 34/100
# 2739/2739 [==============================] - 0s 88us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0320
# Epoch 35/100
# 2739/2739 [==============================] - 0s 89us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0318
# Epoch 36/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0306
# Epoch 37/100
# 2739/2739 [==============================] - 0s 91us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0306
# Epoch 38/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0309
# Epoch 39/100
# 2739/2739 [==============================] - 0s 87us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0299
# Epoch 40/100
# 2739/2739 [==============================] - 0s 94us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0296
# Epoch 41/100
# 2739/2739 [==============================] - 0s 96us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0298
# Epoch 42/100
# 2739/2739 [==============================] - 0s 100us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0293
# Epoch 43/100
# 2739/2739 [==============================] - 0s 109us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0287
# Epoch 44/100
# 2739/2739 [==============================] - 0s 103us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0285
# Epoch 45/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0286
# Epoch 46/100
# 2739/2739 [==============================] - 0s 96us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0276
# Epoch 47/100
# 2739/2739 [==============================] - 0s 97us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0277
# Epoch 48/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0270
# Epoch 49/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0268
# Epoch 50/100
# 2739/2739 [==============================] - 0s 114us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0265
# Epoch 51/100
# 2739/2739 [==============================] - 0s 106us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0263
# Epoch 52/100
# 2739/2739 [==============================] - 0s 101us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0261
# Epoch 53/100
# 2739/2739 [==============================] - 0s 101us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0261
# Epoch 54/100
# 2739/2739 [==============================] - 0s 102us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0257
# Epoch 55/100
# 2739/2739 [==============================] - 0s 96us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0251
# Epoch 56/100
# 2739/2739 [==============================] - 0s 102us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0256
# Epoch 57/100
# 2739/2739 [==============================] - 0s 96us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0253
# Epoch 58/100
# 2739/2739 [==============================] - 0s 97us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0246
# Epoch 59/100
# 2739/2739 [==============================] - 0s 110us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0250
# Epoch 60/100
# 2739/2739 [==============================] - 0s 98us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0244
# Epoch 61/100
# 2739/2739 [==============================] - 0s 101us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0241
# Epoch 62/100
# 2739/2739 [==============================] - 0s 105us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0244
# Epoch 63/100
# 2739/2739 [==============================] - 0s 106us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0241
# Epoch 64/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0240
# Epoch 65/100
# 2739/2739 [==============================] - 0s 97us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0240
# Epoch 66/100
# 2739/2739 [==============================] - 0s 94us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0236
# Epoch 67/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0232
# Epoch 68/100
# 2739/2739 [==============================] - 0s 94us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0235
# Epoch 69/100
# 2739/2739 [==============================] - 0s 97us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0229
# Epoch 70/100
# 2739/2739 [==============================] - 0s 94us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0229
# Epoch 71/100
# 2739/2739 [==============================] - 0s 94us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0226
# Epoch 72/100
# 2739/2739 [==============================] - 0s 94us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0225
# Epoch 73/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0224
# Epoch 74/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0223
# Epoch 75/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0224
# Epoch 76/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0219
# Epoch 77/100
# 2739/2739 [==============================] - 0s 96us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0219
# Epoch 78/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0221
# Epoch 79/100
# 2739/2739 [==============================] - 0s 108us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0216
# Epoch 80/100
# 2739/2739 [==============================] - 0s 105us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0215
# Epoch 81/100
# 2739/2739 [==============================] - 0s 94us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0211
# Epoch 82/100
# 2739/2739 [==============================] - 0s 106us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0215
# Epoch 83/100
# 2739/2739 [==============================] - 0s 102us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0217
# Epoch 84/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0207
# Epoch 85/100
# 2739/2739 [==============================] - 0s 91us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0209
# Epoch 86/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0211
# Epoch 87/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0206
# Epoch 88/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0209
# Epoch 89/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0206
# Epoch 90/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0208
# Epoch 91/100
# 2739/2739 [==============================] - 0s 93us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0204
# Epoch 92/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0204
# Epoch 93/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0205
# Epoch 94/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0202
# Epoch 95/100
# 2739/2739 [==============================] - 0s 90us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0200
# Epoch 96/100
# 2739/2739 [==============================] - 0s 95us/step - loss: 9.9214e-04 - mean_squared_error: 9.9214e-04 - mean_absolute_error: 0.0200
# Epoch 97/100
# 2739/2739 [==============================] - 0s 92us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0202
# Epoch 98/100
# 2739/2739 [==============================] - 0s 96us/step - loss: 9.6751e-04 - mean_squared_error: 9.6751e-04 - mean_absolute_error: 0.0196
# Epoch 99/100
# 2739/2739 [==============================] - 0s 114us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0202
# Epoch 100/100
# 2739/2739 [==============================] - 0s 100us/step - loss: 9.4420e-04 - mean_squared_error: 9.4420e-04 - mean_absolute_error: 0.0195

# %%
error_function_list = [lambda y_t, y_p: list(map(lambda t, p: abs(t - p), y_t, y_p))]
errors = nn.compute_errors(model, x, y_true, y_pred, error_function_list)

opacity = 1
color = '#FED487'
edge_color = 'black'
num_errors = len(errors)
y_size = nn.get_y_size_from_errors(errors)

# %%
# Error bins.
error_ranges = [(0.0, 1.0)] * 3
data_percentages_bins = nn.mutiple_error_bins_data_percentage(errors, error_ranges = error_ranges)

fig, axes = plt.subplots(3, figsize=(6, 12))
(ax1, ax2, ax3) = axes

for i in range(y_size):
    data_percentages, bins = data_percentages_bins[0][i]
    width = 1 * (bins[1] - bins[0])
    center = (bins[:-1] + bins[1:]) / 2
    axes[i].bar(center, data_percentages, align='center', width=width, color = color, edgecolor = edge_color, alpha = opacity)

plt.setp(axes, xticks = np.arange(0.0, 1.1, 0.1), yticks = np.arange(0.0, 1.1, 0.1))
fig.suptitle("Percentage of data by error bins", fontsize = 16)
ax1.set_title('Win ratio')
ax2.set_title('Loss ratio')
ax3.set_title('Draw ratio')
for ax in axes:
    ax.set_xlabel('Error bins')
    ax.set_ylabel('Percentage of data')
fig.subplots_adjust(top = 0.9, hspace = 0.4)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# Mean error.
mean_std_error = nn.mutiple_mean_standard_deviation_error_by_num_empty_squares(x, errors)
num_empty_squares = np.array(range(ttt.SIZE + 1))

fig, axes = plt.subplots(3, figsize=(6, 12))
(ax1, ax2, ax3) = axes

for i in range(y_size):
    mean_std = mean_std_error[0][i]
    mean = [mean for (mean, std) in  mean_std]
    std = [std for (mean, std) in  mean_std]
    axes[i].bar(num_empty_squares, mean, yerr = std, color = color, error_kw = {'ecolor': '0.65'}, edgecolor = edge_color, alpha = opacity)

plt.setp(axes, xticks = range(10), yticks = np.arange(0.0, 1.1, 0.1))
fig.suptitle("Mean error by number of empty squares", fontsize = 16)
ax1.set_title('Win ratio')
ax2.set_title('Loss ratio')
ax3.set_title('Draw ratio')
for ax in axes:
    ax.set_xlabel('Number of empty squares')
    ax.set_ylabel('Mean error')
    ax.set_ylim(ymin=0.0)
fig.subplots_adjust(top = 0.9, hspace = 0.4)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
