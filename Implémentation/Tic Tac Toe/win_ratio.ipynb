# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
import random
import numpy as np

import tic_tac_toe as ttt
import data_set as ds
import neural_network as nn

seed = 867342
data_set_file_name = "data_set.csv"
model_file_name = "model.h5"

random.seed(seed)
np.random.seed(int(seed))

data_set = ds.read_data_set(data_set_file_name)
training_set = data_set
x, y_true = nn.get_data_for_neural_network(training_set, nn.get_win_ratio)
model = nn.create_fit_model(x, y_true, model_file_name = model_file_name)
y_pred = model.predict([nn.convert_grid_for_neural_network(grid) for grid in x], batch_size = 1)
# Out:
# Epoch 1/100
# 5478/5478 [==============================] - 1s 190us/step - loss: 0.0482 - mean_squared_error: 0.0482 - mean_absolute_error: 0.1649
# Epoch 2/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0229 - mean_squared_error: 0.0229 - mean_absolute_error: 0.1155
# Epoch 3/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0995
# Epoch 4/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0147 - mean_squared_error: 0.0147 - mean_absolute_error: 0.0906
# Epoch 5/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0129 - mean_squared_error: 0.0129 - mean_absolute_error: 0.0847
# Epoch 6/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0113 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0791
# Epoch 7/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0101 - mean_squared_error: 0.0101 - mean_absolute_error: 0.0742
# Epoch 8/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0096 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0716
# Epoch 9/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0086 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0682
# Epoch 10/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0079 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0644
# Epoch 11/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0075 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0630
# Epoch 12/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0069 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0603
# Epoch 13/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0069 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0588
# Epoch 14/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0064 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0575
# Epoch 15/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0061 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0556
# Epoch 16/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0060 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0552
# Epoch 17/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0057 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0530
# Epoch 18/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0054 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0527
# Epoch 19/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0051 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0510
# Epoch 20/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0050 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0499
# Epoch 21/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0048 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0489
# Epoch 22/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0046 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0475
# Epoch 23/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0045 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0472
# Epoch 24/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0045 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0470
# Epoch 25/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0044 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0459
# Epoch 26/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0040 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0446
# Epoch 27/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0040 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0448
# Epoch 28/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0037 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0428
# Epoch 29/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0038 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0429
# Epoch 30/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0035 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0418
# Epoch 31/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0410
# Epoch 32/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0405
# Epoch 33/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0399
# Epoch 34/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0031 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0392
# Epoch 35/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0031 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0392
# Epoch 36/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0030 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0381
# Epoch 37/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0030 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0381
# Epoch 38/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0375
# Epoch 39/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0370
# Epoch 40/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0362
# Epoch 41/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0363
# Epoch 42/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0361
# Epoch 43/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0354
# Epoch 44/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0351
# Epoch 45/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0346
# Epoch 46/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0340
# Epoch 47/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0335
# Epoch 48/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0339
# Epoch 49/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0327
# Epoch 50/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0327
# Epoch 51/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0327
# Epoch 52/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0325
# Epoch 53/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0320
# Epoch 54/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0319
# Epoch 55/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0312
# Epoch 56/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0312
# Epoch 57/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0309
# Epoch 58/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0309
# Epoch 59/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0306
# Epoch 60/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0301
# Epoch 61/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0298
# Epoch 62/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0294
# Epoch 63/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0298
# Epoch 64/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0297
# Epoch 65/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0292
# Epoch 66/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0294
# Epoch 67/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0285
# Epoch 68/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0285
# Epoch 69/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0287
# Epoch 70/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0279
# Epoch 71/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0281
# Epoch 72/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0280
# Epoch 73/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0275
# Epoch 74/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0275
# Epoch 75/100
# 5478/5478 [==============================] - 0s 77us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0277
# Epoch 76/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0272
# Epoch 77/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0269
# Epoch 78/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0271
# Epoch 79/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0265
# Epoch 80/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0263
# Epoch 81/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0266
# Epoch 82/100
# 5478/5478 [==============================] - 0s 88us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0265
# Epoch 83/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0261
# Epoch 84/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0261
# Epoch 85/100
# 5478/5478 [==============================] - 0s 87us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0261
# Epoch 86/100
# 5478/5478 [==============================] - 0s 90us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0259
# Epoch 87/100
# 5478/5478 [==============================] - 1s 102us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0255
# Epoch 88/100
# 5478/5478 [==============================] - 0s 90us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0255
# Epoch 89/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0252
# Epoch 90/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0255
# Epoch 91/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0251
# Epoch 92/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0248
# Epoch 93/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0251
# Epoch 94/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0250
# Epoch 95/100
# 5478/5478 [==============================] - 0s 88us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0246
# Epoch 96/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0245
# Epoch 97/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0244
# Epoch 98/100
# 5478/5478 [==============================] - 1s 114us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0245
# Epoch 99/100
# 5478/5478 [==============================] - 1s 97us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0244
# Epoch 100/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0242

# %%
"""
import keras
model = keras.models.load_model("model_1000_epochs.h5")
#model = keras.models.load_model("model.h5")
y_pred = model.predict([nn.convert_grid_for_neural_network(grid) for grid in x], batch_size = 1)
"""
# Out:
# '\nimport keras\nmodel = keras.models.load_model("model_1000_epochs.h5")\n#model = keras.models.load_model("model.h5")\ny_pred = model.predict([nn.convert_grid_for_neural_network(grid) for grid in x], batch_size = 1)\n'

# %%
error_function_list = [lambda y_t, y_p: list(map(lambda t, p: abs(t - p), y_t, y_p))]
errors = nn.compute_errors(model, x, y_true, y_pred, error_function_list)

opacity = 0.5
color = 'orange'
edge_color = 'black'
mean_color = 'orange'
median_color = 'red'

# %%
# Error bins.
data_percentages, bins = nn.error_bins_data_percentage(errors[0][0], 10, (0.0, 1.0))

width = 1 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
fig = plt.figure()
plt.bar(center, data_percentages, align='center', width=width, color = color, edgecolor = edge_color, alpha = opacity)
plt.xticks(np.arange(0.0, 1.1, 0.1))
plt.yticks(np.arange(0.0, 1.1, 0.1))
plt.title('Percentage of data by error bins')
plt.xlabel('Error bins')
plt.ylabel('Percentage of data')
plt.show()

"""
Alternative 1:
df = pd.DataFrame({'Errors' : errors})

fig = plt.figure()
plt.hist(df.values, bins=bins, edgecolor="k")
plt.show()

Alternative 2:
center = (bins[1:] + bins[:-1]) / 2
fig = plt.figure()
plt.hist(center, bins=len(data_percentages), weights=data_percentages, range=(min(bins), max(bins)))
plt.show()
"""
# Out:
# <img src="data:image/png;base64,..." width="640">
# '\nAlternative 1:\ndf = pd.DataFrame({\'Errors\' : errors})\n\nfig = plt.figure()\nplt.hist(df.values, bins=bins, edgecolor="k")\nplt.show()\n\nAlternative 2:\ncenter = (bins[1:] + bins[:-1]) / 2\nfig = plt.figure()\nplt.hist(center, bins=len(data_percentages), weights=data_percentages, range=(min(bins), max(bins)))\nplt.show()\n'

# %%
# Mean error.
mean_std = nn.mean_standard_deviation_error_by_num_empty_squares(x, errors[0][0])
mean = [mean for (mean, std) in  mean_std]
std = [std for (mean, std) in  mean_std]

num_empty_squares = np.array(range(ttt.SIZE + 1))

fig = plt.figure()
plt.bar(num_empty_squares, mean, yerr = std, color = color, error_kw = {'ecolor': '0.65'}, edgecolor = edge_color, alpha = opacity)
plt.xticks(range(10))
plt.yticks(np.arange(0.0, 1.1, 0.1))
plt.title('Mean error by number of empty squares')
plt.xlabel('Number of empty squares')
plt.ylabel('Mean error')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Boxplot of y_true.
bins = nn.filter_grids_by_empty_squares(x, y_true)
for i, bi in enumerate(bins):
	bins[i] = [y_t for (grid, y_t) in bi]

num_empty_squares = np.array(range(ttt.SIZE + 1))

fig = plt.figure()
bplot = plt.boxplot(bins, showmeans = True, meanline = True)
plt.xticks(range(1, ttt.SIZE + 2), range(ttt.SIZE + 1))
plt.yticks(np.arange(0.0, 1.1, 0.1))
fig.axes[0].set_ylim(-0.05, 1.05)
plt.title('Win ratio — True output by number of empty squares')
plt.xlabel('Number of empty squares')
plt.ylabel('True output')
plt.setp(bplot['means'], color = mean_color)
plt.setp(bplot['medians'], color = median_color)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Boxplot of y_pred.
bins = nn.filter_grids_by_empty_squares(x, y_pred)
for i, bi in enumerate(bins):
	bins[i] = [y_p for (grid, y_p) in bi]

num_empty_squares = np.array(range(ttt.SIZE + 1))

fig = plt.figure()
bplot = plt.boxplot(bins, showmeans = True, meanline = True)
plt.xticks(range(1, ttt.SIZE + 2), range(ttt.SIZE + 1))
plt.yticks(np.arange(0.0, 1.1, 0.1))
fig.axes[0].set_ylim(-0.05, 1.05)
plt.title('Win ratio — Predicted output by number of empty squares')
plt.xlabel('Number of empty squares')
plt.ylabel('Predicted output output')
plt.setp(bplot['means'], color = mean_color)
plt.setp(bplot['medians'], color = median_color)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Boxplot of errors.
bins = nn.filter_grids_by_empty_squares(x, errors[0][0])
for i, bi in enumerate(bins):
	bins[i] = [err for (grid, err) in bi]

num_empty_squares = np.array(range(ttt.SIZE + 1))

fig = plt.figure()
bplot = plt.boxplot(bins, showmeans = True, meanline = True)
plt.xticks(range(1, ttt.SIZE + 2), range(ttt.SIZE + 1))
plt.yticks(np.arange(0.0, 1.1, 0.1))
fig.axes[0].set_ylim(-0.05, 1.05)
plt.title('Win ratio — Errors by number of empty squares')
plt.xlabel('Number of empty squares')
plt.ylabel('Errors output')
plt.setp(bplot['means'], color = mean_color)
plt.setp(bplot['medians'], color = median_color)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
