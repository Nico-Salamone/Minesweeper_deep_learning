# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
import random
import numpy as np

import tic_tac_toe as ttt
import data_set as ds
import neural_network as nn

seed = 867342
data_set_file_name = "data_set.csv"
model_file_name = "model.h5"

random.seed(seed)
np.random.seed(int(seed))

data_set = ds.read_data_set(data_set_file_name)
training_set = data_set
x, y_true = nn.get_data_for_neural_network(training_set, nn.get_win_loss_draw_ratio)
model = nn.create_fit_model(x, y_true, model_file_name = model_file_name)
y_pred = model.predict([nn.convert_grid_for_neural_network(grid) for grid in x], batch_size = 1)
# Out:
# Using TensorFlow backend.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Epoch 1/100
# 5478/5478 [==============================] - 1s 126us/step - loss: 0.0389 - mean_squared_error: 0.0389 - mean_absolute_error: 0.1360
# Epoch 2/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0911
# Epoch 3/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0785
# Epoch 4/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0707
# Epoch 5/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0095 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0655
# Epoch 6/100
# 5478/5478 [==============================] - 1s 106us/step - loss: 0.0085 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0618
# Epoch 7/100
# 5478/5478 [==============================] - 1s 109us/step - loss: 0.0076 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0579
# Epoch 8/100
# 5478/5478 [==============================] - 1s 114us/step - loss: 0.0068 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0548
# Epoch 9/100
# 5478/5478 [==============================] - 0s 87us/step - loss: 0.0063 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0527
# Epoch 10/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0058 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0505
# Epoch 11/100
# 5478/5478 [==============================] - 0s 91us/step - loss: 0.0055 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0489
# Epoch 12/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0051 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0464
# Epoch 13/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0047 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0450
# Epoch 14/100
# 5478/5478 [==============================] - 0s 87us/step - loss: 0.0045 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0435
# Epoch 15/100
# 5478/5478 [==============================] - 0s 89us/step - loss: 0.0043 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0423
# Epoch 16/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0041 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0413
# Epoch 17/100
# 5478/5478 [==============================] - 0s 90us/step - loss: 0.0039 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0400
# Epoch 18/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0038 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0394
# Epoch 19/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0036 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0383
# Epoch 20/100
# 5478/5478 [==============================] - 0s 89us/step - loss: 0.0034 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0372
# Epoch 21/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0370
# Epoch 22/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0033 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0363
# Epoch 23/100
# 5478/5478 [==============================] - 0s 87us/step - loss: 0.0031 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0352
# Epoch 24/100
# 5478/5478 [==============================] - 0s 89us/step - loss: 0.0031 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0351
# Epoch 25/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0029 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0344
# Epoch 26/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0334
# Epoch 27/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0329
# Epoch 28/100
# 5478/5478 [==============================] - 1s 93us/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0326
# Epoch 29/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0315
# Epoch 30/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0315
# Epoch 31/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0308
# Epoch 32/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0305
# Epoch 33/100
# 5478/5478 [==============================] - 0s 88us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0298
# Epoch 34/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0298
# Epoch 35/100
# 5478/5478 [==============================] - 1s 91us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0296
# Epoch 36/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0291
# Epoch 37/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0287
# Epoch 38/100
# 5478/5478 [==============================] - 0s 88us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0284
# Epoch 39/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0279
# Epoch 40/100
# 5478/5478 [==============================] - 1s 97us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0280
# Epoch 41/100
# 5478/5478 [==============================] - 1s 93us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0275
# Epoch 42/100
# 5478/5478 [==============================] - 0s 87us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0270
# Epoch 43/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0264
# Epoch 44/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0265
# Epoch 45/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0260
# Epoch 46/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0261
# Epoch 47/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0257
# Epoch 48/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0255
# Epoch 49/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0251 0s - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolu
# Epoch 50/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0248
# Epoch 51/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0247
# Epoch 52/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0245
# Epoch 53/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0242
# Epoch 54/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0243
# Epoch 55/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0015 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0239
# Epoch 56/100
# 5478/5478 [==============================] - 1s 93us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0238
# Epoch 57/100
# 5478/5478 [==============================] - 0s 89us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0238
# Epoch 58/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0237
# Epoch 59/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0229
# Epoch 60/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0232
# Epoch 61/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0229
# Epoch 62/100
# 5478/5478 [==============================] - 0s 90us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0227
# Epoch 63/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0225
# Epoch 64/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0226
# Epoch 65/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0224
# Epoch 66/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0221
# Epoch 67/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0221
# Epoch 68/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0217
# Epoch 69/100
# 5478/5478 [==============================] - 1s 93us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0217
# Epoch 70/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0216
# Epoch 71/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0213
# Epoch 72/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0216
# Epoch 73/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0215
# Epoch 74/100
# 5478/5478 [==============================] - 0s 87us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0211
# Epoch 75/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0208
# Epoch 76/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0209
# Epoch 77/100
# 5478/5478 [==============================] - 0s 89us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0207
# Epoch 78/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0208
# Epoch 79/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0204
# Epoch 80/100
# 5478/5478 [==============================] - 0s 87us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0206
# Epoch 81/100
# 5478/5478 [==============================] - 0s 89us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0205
# Epoch 82/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0201
# Epoch 83/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0202
# Epoch 84/100
# 5478/5478 [==============================] - 0s 84us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0201
# Epoch 85/100
# 5478/5478 [==============================] - 1s 91us/step - loss: 0.0011 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0202
# Epoch 86/100
# 5478/5478 [==============================] - 0s 86us/step - loss: 0.0010 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0199
# Epoch 87/100
# 5478/5478 [==============================] - 0s 90us/step - loss: 9.9777e-04 - mean_squared_error: 9.9777e-04 - mean_absolute_error: 0.0197
# Epoch 88/100
# 5478/5478 [==============================] - 0s 79us/step - loss: 9.8512e-04 - mean_squared_error: 9.8512e-04 - mean_absolute_error: 0.0196
# Epoch 89/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 9.7405e-04 - mean_squared_error: 9.7405e-04 - mean_absolute_error: 0.0196
# Epoch 90/100
# 5478/5478 [==============================] - 0s 83us/step - loss: 9.3264e-04 - mean_squared_error: 9.3264e-04 - mean_absolute_error: 0.0192
# Epoch 91/100
# 5478/5478 [==============================] - 0s 88us/step - loss: 9.3954e-04 - mean_squared_error: 9.3954e-04 - mean_absolute_error: 0.0191
# Epoch 92/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 9.5117e-04 - mean_squared_error: 9.5117e-04 - mean_absolute_error: 0.0193
# Epoch 93/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 9.2986e-04 - mean_squared_error: 9.2986e-04 - mean_absolute_error: 0.0191
# Epoch 94/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 9.3005e-04 - mean_squared_error: 9.3005e-04 - mean_absolute_error: 0.0191
# Epoch 95/100
# 5478/5478 [==============================] - 0s 82us/step - loss: 9.1780e-04 - mean_squared_error: 9.1780e-04 - mean_absolute_error: 0.0191
# Epoch 96/100
# 5478/5478 [==============================] - 0s 80us/step - loss: 9.0020e-04 - mean_squared_error: 9.0020e-04 - mean_absolute_error: 0.0188
# Epoch 97/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 8.9227e-04 - mean_squared_error: 8.9227e-04 - mean_absolute_error: 0.0187
# Epoch 98/100
# 5478/5478 [==============================] - 0s 78us/step - loss: 8.9318e-04 - mean_squared_error: 8.9318e-04 - mean_absolute_error: 0.0187
# Epoch 99/100
# 5478/5478 [==============================] - 0s 81us/step - loss: 8.7736e-04 - mean_squared_error: 8.7736e-04 - mean_absolute_error: 0.0185
# Epoch 100/100
# 5478/5478 [==============================] - 0s 85us/step - loss: 8.7161e-04 - mean_squared_error: 8.7161e-04 - mean_absolute_error: 0.0186

# %%
error_function_list = [lambda y_t, y_p: list(map(lambda t, p: abs(t - p), y_t, y_p))]
errors = nn.compute_errors(model, x, y_true, y_pred, error_function_list)

opacity = 0.5
color = 'orange'
edge_color = 'black'
num_errors = len(errors)
y_size = nn.get_y_size_from_errors(errors)

# %%
# Error bins.
error_ranges = [(0.0, 1.0)] * 3
data_percentages_bins = nn.mutiple_error_bins_data_percentage(errors, error_ranges = error_ranges)

fig, axes = plt.subplots(3, figsize=(6, 12))
(ax1, ax2, ax3) = axes

for i in range(y_size):
    data_percentages, bins = data_percentages_bins[0][i]
    width = 1 * (bins[1] - bins[0])
    center = (bins[:-1] + bins[1:]) / 2
    axes[i].bar(center, data_percentages, align='center', width=width, color = color, edgecolor = edge_color, alpha = opacity)

plt.setp(axes, xticks = np.arange(0.0, 1.1, 0.1), yticks = np.arange(0.0, 1.1, 0.1))
fig.suptitle("Percentage of data by error bins", fontsize = 16)
ax1.set_title('Win ratio')
ax2.set_title('Loss ratio')
ax3.set_title('Draw ratio')
for ax in axes:
    ax.set_xlabel('Error bins')
    ax.set_ylabel('Percentage of data')
fig.subplots_adjust(top = 0.9, hspace = 0.4)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# Mean error.
mean_std_error = nn.mutiple_mean_standard_deviation_error_by_num_empty_squares(x, errors)
num_empty_squares = np.array(range(ttt.SIZE + 1))

fig, axes = plt.subplots(3, figsize=(6, 12))
(ax1, ax2, ax3) = axes

for i in range(y_size):
    mean_std = mean_std_error[0][i]
    mean = [mean for (mean, std) in  mean_std]
    std = [std for (mean, std) in  mean_std]
    axes[i].bar(num_empty_squares, mean, yerr = std, color = color, error_kw = {'ecolor': '0.65'}, edgecolor = edge_color, alpha = opacity)

plt.setp(axes, xticks = range(10), yticks = np.arange(0.0, 1.1, 0.1))
fig.suptitle("Mean error by number of empty squares", fontsize = 16)
ax1.set_title('Win ratio')
ax2.set_title('Loss ratio')
ax3.set_title('Draw ratio')
for ax in axes:
    ax.set_xlabel('Number of empty squares')
    ax.set_ylabel('Mean error')
    ax.set_ylim(ymin=0.0)
fig.subplots_adjust(top = 0.9, hspace = 0.4)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
